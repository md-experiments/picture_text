# %%
import pandas as pd

# %%
cord_path='../cord_19_embeddings_2020-09-27.csv'
df = pd.read_csv(cord_path, index_col=0,)

# %%
df.head()
# Out:
#           -2.939983606338501  -6.312200546264648  -1.0459030866622925  \
# ug7v899j
# 02tnwd4m            4.688466           -6.284460             1.228246
# ejv2xln0            0.559920           -6.754057             2.271945
# 2b73a28n            2.352540           -3.997074             2.399774
# 9785vg6d           -1.290922           -5.849864             1.557572
# zjufx4fo            2.721076           -0.431015             2.179080
#
#           5.164162635803223  -0.32564637064933777  -2.507413387298584  \
# ug7v899j
# 02tnwd4m           5.569900              5.224824           -0.406792
# ejv2xln0           7.644496              3.592816           -1.320622
# 2b73a28n           4.594238              2.343638            1.867916
# 9785vg6d           7.989901              5.805941           -4.537519
# zjufx4fo           6.504300             -0.202242           -0.894725
#
#           1.735608696937561  1.9363566637039185  0.622501015663147  \
# ug7v899j
# ...

# %%
id_unq=df.index.unique()

# %%
len(id_unq)
# Out:
# 268334

# %%
df.shape
# Out:
# (282024, 768)

# %%
id_unq[:4]
# Out:
# Index(['02tnwd4m', 'ejv2xln0', '2b73a28n', '9785vg6d'], dtype='object', name='ug7v899j')

# %%
bioarhiv_path='../biorxiv_clean.csv'
bio_df = pd.read_csv(bioarhiv_path, index_col=0,)

# %%
bio_df.head()
# Out:
#                                                                                       title  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367  The Effectiveness of Targeted Quarantine for M...
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec     Evaluation of Group Testing for SARS-CoV-2 RNA
# e686d1ce1540026ecb100c09f99ed091c139b92c  Why estimating population-based case fatality ...
# c6039f8933305c9f44a44c81a15b321b6c2848dc  Far-UVC light: A new tool to control the sprea...
# 073d74442e2655d79b0b3f764a627ec667ad422c  Quantifying SARS-CoV-2 transmission suggests e...
#
#                                                                                     authors  \
# paper_id
# bbf09194127619f57b3ddf5daf684593a5831367             Alastair Jamieson-Lane, Eric Cytrnbaum
# 2a21fdd15e07c89c88e8c2f6c6ab5692568876ec  Nasa Sinnott-Armstrong, Daniel L Klein, Brenda...
# e686d1ce1540026ecb100c09f99ed091c139b92c              Lucas Böttcher, Mingtao Xia, Tom Chou
# ...

# %%
meta_data='../archive/metadata.csv'
meta_df = pd.read_csv(bioarhiv_path,)

# %%
meta_df['id_eight']=meta_df['paper_id'].apply(lambda x: x[:8])

# %%
meta_df.head()
# Out:
#                                    paper_id  \
# 0  14572a7a9b3e92b960d92d9755979eb94c448bb5
# 1  bb790e8366da63c4f5e2d64fa7bbd5673b93063c
# 2  24f204ce5a1a4d752dc9ea7525082d225caed8b3
# 3  f5bc62a289ef384131f592ec3a8852545304513a
# 4  ab78a42c688ac199a2d5669e42ee4c39ff0df2b8
#
#                                                title  \
# 0  Immune Parameters of Dry Cows Fed Mannan Oligo...
# 1  Discontinuous Transcription or RNA Processing ...
# 2                                                NaN
# 3                        Pediatric Natural Deaths 30
# 4  A real-time convective PCR machine in a capill...
#
#                                              authors  \
# 0     S T Franklin, M C Newman, K E Newman, K I Meek
# 1  Beate Schwer, Paolo Vista, Jan C Vos, Hendrik ...
# 2                                                NaN
# 3                Elizabeth C Burton, Nicole A Singer
# 4  Yi-Fan Hsieh, Da-Sheng Lee, Ping-Hei Chen, Sha...
#
# ...

# %%
meta_df.raw_bibliography.iloc[3]
# Out:
# '{\'BIBREF0\': {\'ref_id\': \'b0\', \'title\': \'In athletes who experienced sudden death or in those who experienced cardiac arrest before medical intervention, postmortem examination should include sampling for toxicology, hemoglobin determination by electrophoresis or high-pressure liquid chromatography (HPLC) if sickle cell status has not previously been determined, microbial cultures\', \'authors\': [{\'first\': \'\', \'middle\': [], \'last\': \'Thogmartin\', \'suffix\': \'\'}], \'year\': 2009, \'venue\': \'\', \'volume\': \'\', \'issn\': \'\', \'pages\': \'\', \'other_ids\': {}}, \'BIBREF1\': {\'ref_id\': \'b1\', \'title\': \'Pulmonary edema and thromboemboli are common findings in individuals with SCT. There may be evidence of splenomegaly in cases of SCD, splenic sequestration, or evidence of splenic rupture. Alternatively in adolescents and young adults with SCD, the spleen may be small, scarred, and infarcted or consist only of fibrous tissue (e.g., autosplenectomy). Typica
# ...
